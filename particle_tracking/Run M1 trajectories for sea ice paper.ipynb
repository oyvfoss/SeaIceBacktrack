# %% [markdown]
# ### Run trajectories from M1 mooring *(08.2018 - 31.12.2021)*
#
# Computing back-trajectories from the M1 mooring every two days from 1 Aug 2018 through December 2021.
#
# - Using a **2km IBCAO coastline excluding Svalbard** to check interaction with coasts (*MASK*)
# - Linear interpolation (*griddata*) between
# - End criteria (*ABC*):
#
#     - Nearest non-landmasked grid cell is NaN (<15% sea ice concentration).
#     - Ice particle has stopped moving (|u|<100 m /day for 3 consecutive days).
#     - Particle has drifted onto land as defined by *MASK*.
#
# - Saving to *output/back_trajectories_m1_v1.p*

# %% [markdown]
# *NOTE*: This is not optimized for speed. Takes **days** to run this on a laptop.

# %%
#Imports 
import pickle
import datetime

# %% [markdown]
# #### Load data and class/methods from other notebooks

# %%
print('Running other notebooks: Preparing data..\r', end = '')
# %run "Load and prepare data.ipynb"
print('Running other notebooks: Defining particle tracking class..', end = '')
# %run "Define particle tracking class.ipynb"
print('  ..done.')
# Out:
# Running other notebooks: Defining particle tracking class..  ..done.

# %% [markdown]
# #### Set mooring name and coordinates

# %%
moor = 'm1'
lon = 28.097167
lat = 79.589333

# %% [markdown]
# #### Set time min and max

# %%
time_start =  datetime.datetime(2018, 8, 1, tzinfo=datetime.timezone.utc)
time_end = datetime.datetime(2021, 12, 31, tzinfo=datetime.timezone.utc)
time_gap_days = 2

# %% [markdown]
# #### Set output file

# %%
datadir_out = './output/'  
savenm =datadir_out + 'back_trajectories_%s_v1.p'%moor
print(savenm)

# %% [markdown]
# # Trajectories

# %% [markdown]
# #### Set dictonary with input parameters
# We  will iterate over the variable *time0* - everything else stays the same.

# %%
IC_dict0 = {'D':D, 'lat0':lat, 'lon0':lon, 'time0':None, 'MASK':MASK, 
              'interp_method':'linear', 'end_criteria':'ABC' }

# %% [markdown]
# ## Evaluation loop
#
# Looping through every *time_gap_days*th day from *time_start* to *time_end* and computing the back-trajectory from M1.
#
# *Takes multiple days to run this on a laptop.*
#
# -> Script allows for picking up an interrupted run *(load_old = True)*

# %%
TRAJS = []
lat0, lon0 =  lat, lon

# Set load_old=True to load previously stored file and pick up where 
# that ends (useful for picking up an interrupted run). 
load_old = False
if load_old:
    Ps =pickle_load(savenm)
    time_ = num2date(date2num(Ps[-1]['time0']))
else:
    time_ = time_start

# - Loop through time steps
# - Storing output (one dictionary per trajectory) in the dictionary TRAJS
# - Saving TRAJS to disk along the way

count = 0

while time_ < time_end:
    
    # STEP FORWARD #
    # Update the input directory
    count += 1
    time_ = time_ + datetime.timedelta(days=float(time_gap_days))
    IC_dict = IC_dict0.copy()
    IC_dict['time0'] = time_
    
    # EVALUATING #
    # Set up object, compute the trajectory, and save to TRAJS
    
    print('### %i / %s.. ### '%(count, time_.strftime('%d %b %Y')))
    P = ice_particle(IC_dict)
    P.backtrack()
    TRAJS += [P.to_dict()]
    
    # SAVING ##
    # Saving all long trajectories (>50 km)
    # Otherwise, save every 10th
    
    save_it = False
    if P.travel_time_days>50:
        save_it = True
    if count//10 == count/10:
        save_it = True
            
    if save_it:
        with open(savenm, 'wb') as f:
            pickle.dump(TRAJS, f)
        print('SAVING!')
# Out:
# ### 1 / 03 Aug 2018.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ###
2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 648 (27 Sep 2017) - 2056.4 km ..
# SAVING!
# ### 171 / 09 Jul 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 650 (27 Sep 2017) - 2056.5 km ..
# SAVING!
# ### 172 / 11 Jul 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 652 (27 Sep 2017) - 2060.6 km ..
# SAVING!
# ### 173 / 13 Jul 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 649 (02 Oct 2017) - 2070.7 km ..
# SAVING!
# ### 174 / 15 Jul 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 651 (02 Oct 2017) - 2072.0 km ..
# SAVING!
# ### 175 / 17 Jul 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 653 (02 Oct 2017) - 2071.4 km ..
# SAVING!
# ### 176 / 19 Jul 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 654 (03 Oct 2017) - 2092.4 km ..
# SAVING!
# ### 177 / 21 Jul 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 660 (29 Sep 2017) - 2096.4 km ..
# SAVING!
# ### 178 / 23 Jul 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 663 (28 Sep 2017) - 2102.9 km ..
# SAVING!
# ### 179 / 25 Jul 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 659 (04 Oct 2017) - 2109.1 km ..
# SAVING!
# ### 180 / 27 Jul 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 663 (02 Oct 2017) - 2117.0 km ..
# SAVING!
# ### 181 / 29 Jul 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 665 (02 Oct 2017) - 2119.8 km ..
# SAVING!
# ### 182 / 31 Jul 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 667 (02 Oct 2017) - 2120.9 km ..
# SAVING!
# ### 183 / 02 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 669 (02 Oct 2017) - 2121.9 km ..
# SAVING!
# ### 184 / 04 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 671 (02 Oct 2017) - 2122.1 km ..
# SAVING!
# ### 185 / 06 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 673 (02 Oct 2017) - 2123.0 km ..
# SAVING!
# ### 186 / 08 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 675 (02 Oct 2017) - 2123.6 km ..
# SAVING!
# ### 187 / 10 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 677 (02 Oct 2017) - 2125.9 km ..
# SAVING!
# ### 188 / 12 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 674 (07 Oct 2017) - 2129.4 km ..
# SAVING!
# ### 189 / 14 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 679 (04 Oct 2017) - 2129.9 km ..
# SAVING!
# ### 190 / 16 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 681 (04 Oct 2017) - 2129.6 km ..
# SAVING!
# ### 191 / 18 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 683 (04 Oct 2017) - 2130.8 km ..
# SAVING!
# ### 192 / 20 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 685 (04 Oct 2017) - 2128.9 km ..
# SAVING!
# ### 193 / 22 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 687 (04 Oct 2017) - 2129.4 km ..
# SAVING!
# ### 194 / 24 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 689 (04 Oct 2017) - 2130.1 km ..
# SAVING!
# ### 195 / 26 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 691 (04 Oct 2017) - 2130.5 km ..
# SAVING!
# ### 196 / 28 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 693 (04 Oct 2017) - 2128.5 km ..
# SAVING!
# ### 197 / 30 Aug 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 697 (02 Oct 2017) - 2125.3 km ..
# SAVING!
# ### 198 / 01 Sep 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 699 (02 Oct 2017) - 2123.5 km ..
# SAVING!
# ### 199 / 03 Sep 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 692 (11 Oct 2017) - 2079.1 km ..
# SAVING!
# ### 200 / 05 Sep 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 703 (02 Oct 2017) - 2124.0 km ..
# SAVING!
# ### 201 / 07 Sep 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 705 (02 Oct 2017) - 2126.2 km ..
# SAVING!
# ### 202 / 09 Sep 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 705 (04 Oct 2017) - 2129.2 km ..
# SAVING!
# ### 203 / 11 Sep 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step
2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 67 (12 Oct 2019) - 206.3 km ..
# SAVING!
# ### 253 / 20 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 69 (12 Oct 2019) - 207.5 km ..
# SAVING!
# ### 254 / 22 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 71 (12 Oct 2019) - 208.8 km ..
# SAVING!
# ### 255 / 24 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 73 (12 Oct 2019) - 213.0 km ..
# SAVING!
# ### 256 / 26 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 75 (12 Oct 2019) - 212.7 km ..
# SAVING!
# ### 257 / 28 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 77 (12 Oct 2019) - 216.2 km ..
# SAVING!
# ### 258 / 30 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 79 (12 Oct 2019) - 224.6 km ..
# SAVING!
# ### 259 / 01 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 81 (12 Oct 2019) - 225.1 km ..
# SAVING!
# ### 260 / 03 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 83 (12 Oct 2019) - 230.3 km ..
# SAVING!
# ### 261 / 05 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 85 (12 Oct 2019) - 230.9 km ..
# SAVING!
# ### 262 / 07 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 87 (12 Oct 2019) - 232.9 km ..
# SAVING!
# ### 263 / 09 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 84 (17 Oct 2019) - 268.6 km ..
# SAVING!
# ### 264 / 11 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 82 (21 Oct 2019) - 265.7 km ..
# SAVING!
# ### 265 / 13 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 86 (19 Oct 2019) - 276.1 km ..
# SAVING!
# ### 266 / 15 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 88 (19 Oct 2019) - 276.4 km ..
# SAVING!
# ### 267 / 17 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 90 (19 Oct 2019) - 273.9 km ..
# SAVING!
# ### 268 / 19 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 92 (19 Oct 2019) - 280.6 km ..
# SAVING!
# ### 269 / 21 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 91 (22 Oct 2019) - 274.6 km ..
# SAVING!
# ### 270 / 23 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 93 (22 Oct 2019) - 271.3 km ..
# SAVING!
# ### 271 / 25 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 93 (24 Oct 2019) - 264.8 km ..
# SAVING!
# ### 272 / 27 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 95 (24 Oct 2019) - 256.7 km ..
# SAVING!
# ### 273 / 29 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 102 (19 Oct 2019) - 275.0 km ..
# SAVING!
# ### 274 / 31 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 101 (22 Oct 2019) - 253.6 km ..
# SAVING!
# ### 275 / 02 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 103 (22 Oct 2019) - 266.1 km ..
# SAVING!
# ### 276 / 04 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 105 (22 Oct 2019) - 266.2 km ..
# SAVING!
# ### 277 / 06 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 107 (22 Oct 2019) - 266.1 km ..
# SAVING!
# ### 278 / 08 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 107 (24 Oct 2019) - 263.8 km ..
# SAVING!
# ### 279 / 10 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 108 (25 Oct 2019) - 306.7 km ..
# SAVING!
# ### 280 / 12 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 101 (03 Nov 2019) - 319.2 km ..
# SAVING!
# ### 281 / 14 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 110 (27 Oct 2019) - 317.7 km ..
# SAVING!
# ### 282 / 16 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 114 (25 Oct 2019) - 318.2 km ..
# SAVING!
# ### 283 / 18 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 107 (03 Nov 2019) - 310.7 km ..
# SAVING!
# ### 284 / 20 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 110 (02 Nov 2019) - 311.9 km ..
# SAVING!
# ### 285 / 22 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 109 (05 Nov 2019) - 308.4 km ..
# SAVING!
# ### 286 / 24 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 111 (05 Nov 2019) - 305.9 km ..
# SAVING!
# ### 287 / 26 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 114 (04 Nov 2019) - 304.7 km ..
# SAVING!
# ### 288 / 28 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 116 (04 Nov 2019) - 307.1 km ..
# SAVING!
# ### 289 / 01 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 118 (04 Nov 2019) - 307.2 km ..
# SAVING!
# ### 290 / 03 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 120 (04 Nov 2019) - 306.8 km ..
# SAVING!
# ### 291 / 05 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 121 (05 Nov 2019) - 308.3 km ..
# SAVING!
# ### 292 / 07 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 123 (05 Nov 2019) - 309.1 km ..
# SAVING!
# ### 293 / 09 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 125 (05 Nov 2019) - 309.1 km ..
# SAVING!
# ### 294 / 11 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 130 (02 Nov 2019) - 317.6 km ..
# SAVING!
# ### 295 / 13 Mar 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)019) - 351.1 km ..
# SAVING!
# ### 296 / 15 Mar 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)019) - 344.5 km ..
# SAVING!
# ### 297 / 17 Mar 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)019) - 344.1 km ..
# SAVING!
# ### 298 / 19 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 179 (22 Sep 2019) - 569.6 km ..
# SAVING!
# ### 299 / 21 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 181 (22 Sep 2019) - 572.9 km ..
# SAVING!
# ### 300 / 23 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 166 (09 Oct 2019) - 551.4 km ..
# SAVING!
# ### 301 / 25 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 168 (09 Oct 2019) - 554.6 km ..
# SAVING!
# ### 302 / 27 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 187 (22 Sep 2019) - 570.8 km ..
# SAVING!
# ### 303 / 29 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 209 (02 Sep 2019) - 625.3 km ..
# SAVING!
# ### 304 / 31 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 547 (01 Oct 2018) - 1577.5 km ..
# SAVING!
# ### 305 / 02 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 549 (01 Oct 2018) - 1589.5 km ..
# SAVING!
# ### 306 / 04 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 542 (10 Oct 2018) - 1614.7 km ..
# SAVING!
# ### 307 / 06 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 544 (10 Oct 2018) - 1620.9 km ..
# SAVING!
# ### 308 / 08 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 546 (10 Oct 2018) - 1653.4 km ..
# SAVING!
# ### 309 / 10 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 548 (10 Oct 2018) - 1657.8 km ..
# SAVING!
# ### 310 / 12 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 550 (10 Oct 2018) - 1661.0 km ..
# SAVING!
# ### 311 / 14 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 552 (10 Oct 2018) - 1647.1 km ..
# SAVING!
# ### 312 / 16 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 554 (10 Oct 2018) - 1605.4 km ..
# SAVING!
# ### 313 / 18 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 556 (10 Oct 2018) - 1599.6 km ..
# SAVING!
# ### 314 / 20 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 558 (10 Oct 2018) - 1650.1 km ..
# SAVING!
# ### 315 / 22 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 559 (11 Oct 2018) - 1716.8 km ..
# SAVING!
# ### 316 / 24 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 556 (16 Oct 2018) - 1739.0 km ..
# SAVING!
# ### 317 / 26 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 556 (18 Oct 2018) - 1746.3 km ..
# SAVING!
# ### 318 / 28 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 558 (18 Oct 2018) - 1746.6 km ..
# SAVING!
# ### 319 / 30 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 560 (18 Oct 2018) - 1753.7 km ..
# SAVING!
# ### 320 / 02 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 562 (18 Oct 2018) - 1754.4 km ..
# SAVING!
# ### 321 / 04 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 564 (18 Oct 2018) - 1753.2 km ..
# SAVING!
# ### 322 / 06 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 568 (16 Oct 2018) - 1734.4 km ..
# SAVING!
# ### 323 / 08 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 570 (16 Oct 2018) - 1721.1 km ..
# SAVING!
# ### 324 / 10 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 571 (17 Oct 2018) - 1743.6 km ..
# SAVING!
# ### 325 / 12 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 578 (12 Oct 2018) - 1715.8 km ..
# SAVING!
# ### 326 / 14 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 581 (11 Oct 2018) - 1694.5 km ..
# SAVING!
# ### 327 / 16 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 583 (11 Oct 2018) - 1688.6 km ..
# SAVING!
# ### 328 / 18 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 585 (11 Oct 2018) - 1689.6 km ..
# SAVING!
# ### 329 / 20 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 587 (11 Oct 2018) - 1689.7 km ..
# SAVING!
# ### 330 / 22 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 589 (11 Oct 2018) - 1689.7 km ..
# SAVING!
# ### 331 / 24 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 591 (11 Oct 2018) - 1684.6 km ..
# SAVING!
# ### 332 / 26 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 594 (10 Oct 2018) - 1677.0 km ..
# SAVING!
# ### 333 / 28 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 596 (10 Oct 2018) - 1674.8 km ..
# SAVING!
# ### 334 / 30 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 598 (10 Oct 2018) - 1677.4 km ..
# SAVING!
# ### 335 / 01 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 600 (10 Oct 2018) - 1675.2 km ..
# SAVING!
# ### 336 / 03 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 601 (11 Oct 2018) - 1683.8 km ..
# SAVING!
# ### 337 / 05 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 603 (11 Oct 2018) - 1696.6 km ..
# SAVING!
# ### 338 / 07 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 605 (11 Oct 2018) - 1684.3 km ..
# SAVING!
# ### 339 / 09 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 607 (11 Oct 2018) - 1677.9 km ..
# SAVING!
# ### 340 / 11 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 609 (11 Oct 2018) - 1685.5 km ..
# SAVING!
# ### 341 / 13 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 611 (11 Oct 2018) - 1700.7 km ..
# SAVING!
# ### 342 / 15 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 606 (18 Oct 2018) - 1746.4 km ..
# SAVING!
# ### 343 / 17 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 607 (19 Oct 2018) - 1756.7 km ..
# SAVING!
# ### 344 / 19 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 609 (19 Oct 2018) - 1766.3 km ..
# SAVING!
# ### 345 / 21 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 611 (19 Oct 2018) - 1771.2 km ..
# SAVING!
# ### 346 / 23 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 611 (21 Oct 2018) - 1777.8 km ..
# SAVING!
# ### 347 / 25 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 613 (21 Oct 2018) - 1781.7 km ..
# SAVING!
# ### 348 / 27 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 616 (20 Oct 2018) - 1785.1 km ..
# SAVING!
# ### 349 / 29 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 616 (22 Oct 2018) - 1787.3 km ..
# SAVING!
# ### 350 / 01 Jul 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 617 (23 Oct 2018) - 1785.9 km ..
# SAVING!
# ### 351 / 03 Jul 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 622 (20 Oct 2018) - 1774.8 km ..
# SAVING!
# ### 352 / 05 Jul 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 624 (20 Oct 2018) - 1753.6 km ..
# SAVING!
# ### 353 / 07 Jul 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 630 (16 Oct 2018) - 1716.1 km ..
# SAVING!
# ### 354 / 09 Jul 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 636 (12 Oct 2018) - 1701.5 km ..
# SAVING!
# ### 355 / 11 Jul 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 356 / 13 Jul 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 2 (11 Jul 2020) - 7.0 km ..
# ### 357 / 15 Jul 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 358 / 17 Jul 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 359 / 19 Jul 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 1 (18 Jul 2020) - 3.6 km ..
# ### 360 / 21 Jul 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# SAVING!
# ### 361 / 23 Jul 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 362 / 25 Jul 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 363 / 27 Jul 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 364 / 29 Jul 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 365 / 31 Jul 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 366 / 02 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 367 / 04 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 368 / 06 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 369 / 08 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 370 / 10 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# SAVING!
# ### 371 / 12 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 372 / 14 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 373 / 16 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 374 / 18 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 375 / 20 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 376 / 22 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 377 / 24 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 378 / 26 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 379 / 28 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 380 / 30 Aug 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# SAVING!
# ### 381 / 01 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 382 / 03 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 383 / 05 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 384 / 07 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 385 / 09 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 386 / 11 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 387 / 13 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 388 / 15 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 389 / 17 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 390 / 19 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# SAVING!
# ### 391 / 21 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 392 / 23 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 393 / 25 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 394 / 27 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 395 / 29 Sep 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 396 / 01 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 397 / 03 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 398 / 05 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 399 / 07 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 400 / 09 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# SAVING!
# ### 401 / 11 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 402 / 13 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 403 / 15 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 404 / 17 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 405 / 19 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 406 / 21 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 407 / 23 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 408 / 25 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 409 / 27 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 410 / 29 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# SAVING!
# ### 411 / 31 Oct 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 412 / 02 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 413 / 04 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 414 / 06 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 415 / 08 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 416 / 10 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 417 / 12 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 418 / 14 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 419 / 16 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 420 / 18 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# SAVING!
# ### 421 / 20 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 422 / 22 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 423 / 24 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 424 / 26 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 425 / 28 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 426 / 30 Nov 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 427 / 02 Dec 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 428 / 04 Dec 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 429 / 06 Dec 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 430 / 08 Dec 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# SAVING!
# ### 431 / 10 Dec 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 432 / 12 Dec 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 433 / 14 Dec 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 434 / 16 Dec 2020.. ###
# Setting up object ..
#  ..done.
# STARTED IN OPEN WATER!
# ### 435 / 18 Dec 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 1 (17 Dec 2020) - 3.0 km ..
# ### 436 / 20 Dec 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 4 (16 Dec 2020) - 20.8 km ..
# ### 437 / 22 Dec 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 6 (16 Dec 2020) - 48.6 km ..
# ### 438 / 24 Dec 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 8 (16 Dec 2020) - 63.9 km ..
# ### 439 / 26 Dec 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 12 (14 Dec 2020) - 86.3 km ..
# ### 440 / 28 Dec 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 14 (14 Dec 2020) - 112.5 km ..
# SAVING!
# ### 441 / 30 Dec 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 16 (14 Dec 2020) - 127.4 km ..
# ### 442 / 01 Jan 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 18 (14 Dec 2020) - 131.6 km ..
# ### 443 / 03 Jan 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 21 (13 Dec 2020) - 139.9 km ..
# ### 444 / 05 Jan 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 23 (13 Dec 2020) - 132.4 km ..
# ### 445 / 07 Jan 2021.. ###
# Setting up object ..
#  ..done.
# BACKTRACKING: Time step 1 (06 Jan 2021) - 6.0 km ..
