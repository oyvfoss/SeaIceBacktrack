# %% [markdown]
# ### Run trajectories from M2 mooring *(08.2018 - 31.12.2021)*
#
# Computing back-trajectories from the M2 mooring every two days from 1 Aug 2018 through December 2021.
#
# - Using a **2km IBCAO coastline excluding Svalbard** to check interaction with coasts (*MASK*)
# - Linear interpolation (*griddata*) between
# - End criteria (*ABC*):
#
#     - Nearest non-landmasked grid cell is NaN (<15% sea ice concentration).
#     - Ice particle has stopped moving (|u|<100 m /day for 3 consecutive days).
#     - Particle has drifted onto land as defined by *MASK*.
#
# - Saving to *output/back_trajectories_m1_v1.p*

# %% [markdown]
# *NOTE*: This is not optimized for speed. Takes **days** to run this on a laptop.

# %%
import pickle
import datetime

# %% [markdown]
# #### Load data and class/methods from other notebooks

# %%
print('Running other notebooks: Preparing data..\r', end = '')
# %run "Load and prepare data.ipynb"
print('Running other notebooks: Defining particle tracking class..', end = '')
# %run "Define particle tracking class.ipynb"
print('  ..done.')
# Out:
# Running other notebooks: Defining particle tracking class..  ..done.

# %% [markdown]
# #### Set mooring name and coordinates

# %%
moor = 'm2'
lon = 32.319833
lat = 79.678833

# %% [markdown]
# #### Set time min and max

# %%
time_start =  datetime.datetime(2018, 8, 1, tzinfo=datetime.timezone.utc)
time_end = datetime.datetime(2021, 12, 31, tzinfo=datetime.timezone.utc)
time_gap_days = 2

# %% [markdown]
# #### Set output file

# %%
datadir_out = './output/'  
savenm =datadir_out + 'back_trajectories_%s_v1.p'%moor
print(savenm)
# Out:
# ./output/back_trajectories_m2_v1.p

# %% [markdown]
# # Trajectories

# %% [markdown]
# #### Set dictonary with input parameters
# We  will iterate over the variable *time0* - everything else stays the same.

# %%
input_dict0 = {'D':D, 'lat0':lat, 'lon0':lon, 'time0':None, 'MASK':MASK, 
              'interp_method':'linear', 'end_criteria':'ABC' }

# %% [markdown]
# ## Evaluation loop
#
# Looping through every *time_gap_days*th day from *time_start* to *time_end* and computing the back-trajectory from M2.
#
# *Takes multiple days to run this on a laptop.*
#
# -> Script allows for picking up an interrupted run *(load_old = True)*

# %%
TRAJS = []
lat0, lon0 =  lat, lon

# Set load_old=True to load previously stored file and pick up where 
# that ends (useful for picking up an interrupted run). 
load_old = False
if load_old:
    Ps =pickle_load(savenm)
    time_ = num2date(date2num(Ps[-1]['time0']))
else:
    time_ = time_start

# - Loop through time steps
# - Storing output (one dictionary per trajectory) in the dictionary TRAJS
# - Saving TRAJS to disk along the way

count = 0

while time_ < time_end:
    
    # STEP FORWARD #
    # Update the input directory
    count += 1
    time_ = time_ + datetime.timedelta(days=float(time_gap_days))
    IC_dict = IC_dict0.copy()
    IC_dict['time0'] = time_
    
    # EVALUATING #
    # Set up object, compute the trajectory, and save to TRAJS
    
    print('### %i / %s.. ### '%(count, time_.strftime('%d %b %Y')))
    P = ice_particle(IC_dict)
    P.backtrack()
    TRAJS += [P.to_dict()]
    
    # SAVING ##
    # Saving all long trajectories (>50 km)
    # Otherwise, save every 10th
    
    save_it = False
    if P.travel_time_days>50:
        save_it = True
    if count//10 == count/10:
        save_it = True
            
    if save_it:
        with open(savenm, 'wb') as f:
            pickle.dump(TRAJS, f)
        print('SAVING!')
# Out:
# ### 1 / 28 May 2019.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline
2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 29 (12 Oct 2019) - 104.1 km ..
# ### 85 / 12 Nov 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 31 (12 Oct 2019) - 104.3 km ..
# ### 86 / 14 Nov 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 33 (12 Oct 2019) - 102.7 km ..
# ### 87 / 16 Nov 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 35 (12 Oct 2019) - 101.8 km ..
# ### 88 / 18 Nov 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 37 (12 Oct 2019) - 92.5 km ..
# ### 89 / 20 Nov 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 39 (12 Oct 2019) - 94.2 km ..
# ### 90 / 22 Nov 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 41 (12 Oct 2019) - 93.2 km ..
# SAVING!
# ### 91 / 24 Nov 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 43 (12 Oct 2019) - 93.6 km ..
# ### 92 / 26 Nov 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 45 (12 Oct 2019) - 98.6 km ...
# ### 93 / 28 Nov 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 47 (12 Oct 2019) - 106.3 km ..
# ### 94 / 30 Nov 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 49 (12 Oct 2019) - 119.4 km ..
# ### 95 / 02 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 52 (11 Oct 2019) - 137.7 km ..
# SAVING!
# ### 96 / 04 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 53 (12 Oct 2019) - 139.6 km ..
# SAVING!
# ### 97 / 06 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 55 (12 Oct 2019) - 168.7 km ..
# SAVING!
# ### 98 / 08 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 51 (18 Oct 2019) - 190.2 km ..
# SAVING!
# ### 99 / 10 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 53 (18 Oct 2019) - 190.6 km ..
# SAVING!
# ### 100 / 12 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 55 (18 Oct 2019) - 191.1 km ..
# SAVING!
# ### 101 / 14 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 57 (18 Oct 2019) - 191.4 km ..
# SAVING!
# ### 102 / 16 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 59 (18 Oct 2019) - 192.8 km ..
# SAVING!
# ### 103 / 18 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 61 (18 Oct 2019) - 193.7 km ..
# SAVING!
# ### 104 / 20 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 62 (19 Oct 2019) - 193.4 km ..
# SAVING!
# ### 105 / 22 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 62 (21 Oct 2019) - 191.5 km ..
# SAVING!
# ### 106 / 24 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 64 (21 Oct 2019) - 193.3 km ..
# SAVING!
# ### 107 / 26 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 66 (21 Oct 2019) - 194.2 km ..
# SAVING!
# ### 108 / 28 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 68 (21 Oct 2019) - 201.8 km ..
# SAVING!
# ### 109 / 30 Dec 2019.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 68 (23 Oct 2019) - 177.6 km ..
# SAVING!
# ### 110 / 01 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 69 (24 Oct 2019) - 179.6 km ..
# SAVING!
# ### 111 / 03 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 71 (24 Oct 2019) - 185.9 km ..
# SAVING!
# ### 112 / 05 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 75 (22 Oct 2019) - 211.8 km ..
# SAVING!
# ### 113 / 07 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 74 (25 Oct 2019) - 201.8 km ..
# SAVING!
# ### 114 / 09 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 67 (03 Nov 2019) - 228.2 km ..
# SAVING!
# ### 115 / 11 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 69 (03 Nov 2019) - 233.6 km ..
# SAVING!
# ### 116 / 13 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 73 (01 Nov 2019) - 232.0 km ..
# SAVING!
# ### 117 / 15 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 74 (02 Nov 2019) - 229.9 km ..
# SAVING!
# ### 118 / 17 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 76 (02 Nov 2019) - 228.4 km ..
# SAVING!
# ### 119 / 19 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 77 (03 Nov 2019) - 230.9 km ..
# SAVING!
# ### 120 / 21 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 77 (05 Nov 2019) - 251.3 km ..
# SAVING!
# ### 121 / 23 Jan 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 302.7 km ..
# SAVING!
# ### 122 / 25 Jan 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 296.1 km ..
# SAVING!
# ### 123 / 27 Jan 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 312.6 km ..
# SAVING!
# ### 124 / 29 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 85 (05 Nov 2019) - 239.0 km ..
# SAVING!
# ### 125 / 31 Jan 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 87 (05 Nov 2019) - 236.7 km ..
# SAVING!
# ### 126 / 02 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 89 (05 Nov 2019) - 243.9 km ..
# SAVING!
# ### 127 / 04 Feb 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 91 (05 Nov 2019) - 246.2 km ..
# SAVING!
# ### 128 / 06 Feb 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 291.5 km ..
# SAVING!
# ### 129 / 08 Feb 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 322.9 km ..
# SAVING!
# ### 130 / 10 Feb 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 316.2 km ..
# SAVING!
# ### 131 / 12 Feb 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 292.1 km ..
# SAVING!
# ### 132 / 14 Feb 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 294.4 km ..
# SAVING!
# ### 133 / 16 Feb 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 292.8 km ..
# SAVING!
# ### 134 / 18 Feb 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 319.5 km ..
# SAVING!
# ### 135 / 20 Feb 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 318.1 km ..
# SAVING!
# ### 136 / 22 Feb 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 316.9 km ..
# SAVING!
# ### 137 / 24 Feb 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 317.3 km ..
# SAVING!
# ### 138 / 26 Feb 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 315.5 km ..
# SAVING!
# ### 139 / 28 Feb 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 319.0 km ..
# SAVING!
# ### 140 / 01 Mar 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 319.7 km ..
# SAVING!
# ### 141 / 03 Mar 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 322.1 km ..
# SAVING!
# ### 142 / 05 Mar 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 322.9 km ..
# SAVING!
# ### 143 / 07 Mar 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 341.9 km ..
# SAVING!
# ### 144 / 09 Mar 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 268.0 km ..
# SAVING!
# ### 145 / 11 Mar 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 268.1 km ..
# SAVING!
# ### 146 / 13 Mar 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)19) - 305.6 km ..
# SAVING!
# ### 147 / 15 Mar 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)019) - 367.1 km ..
# SAVING!
# ### 148 / 17 Mar 2020.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)019) - 376.0 km ..
# SAVING!
# ### 149 / 19 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 153 (18 Oct 2019) - 502.2 km ..
# SAVING!
# ### 150 / 21 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 155 (18 Oct 2019) - 512.6 km ..
# SAVING!
# ### 151 / 23 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 154 (21 Oct 2019) - 472.8 km ..
# SAVING!
# ### 152 / 25 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 156 (21 Oct 2019) - 472.7 km ..
# SAVING!
# ### 153 / 27 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 161 (18 Oct 2019) - 499.7 km ..
# SAVING!
# ### 154 / 29 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 170 (11 Oct 2019) - 519.7 km ..
# SAVING!
# ### 155 / 31 Mar 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 204 (09 Sep 2019) - 581.7 km ..
# SAVING!
# ### 156 / 02 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 206 (09 Sep 2019) - 601.5 km ..
# SAVING!
# ### 157 / 04 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 543 (09 Oct 2018) - 1491.6 km ..
# SAVING!
# ### 158 / 06 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 545 (09 Oct 2018) - 1496.8 km ..
# SAVING!
# ### 159 / 08 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 546 (10 Oct 2018) - 1537.0 km ..
# SAVING!
# ### 160 / 10 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 548 (10 Oct 2018) - 1543.8 km ..
# SAVING!
# ### 161 / 12 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 550 (10 Oct 2018) - 1544.6 km ..
# SAVING!
# ### 162 / 14 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 552 (10 Oct 2018) - 1528.1 km ..
# SAVING!
# ### 163 / 16 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 554 (10 Oct 2018) - 1449.0 km ..
# SAVING!
# ### 164 / 18 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 556 (10 Oct 2018) - 1443.7 km ..
# SAVING!
# ### 165 / 20 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 558 (10 Oct 2018) - 1503.5 km ..
# SAVING!
# ### 166 / 22 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 560 (10 Oct 2018) - 1565.7 km ..
# SAVING!
# ### 167 / 24 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 561 (11 Oct 2018) - 1605.8 km ..
# SAVING!
# ### 168 / 26 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 563 (11 Oct 2018) - 1610.7 km ..
# SAVING!
# ### 169 / 28 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 565 (11 Oct 2018) - 1610.7 km ..
# SAVING!
# ### 170 / 30 Apr 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 567 (11 Oct 2018) - 1613.9 km ..
# SAVING!
# ### 171 / 02 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 569 (11 Oct 2018) - 1613.0 km ..
# SAVING!
# ### 172 / 04 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 571 (11 Oct 2018) - 1607.6 km ..
# SAVING!
# ### 173 / 06 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 574 (10 Oct 2018) - 1588.6 km ..
# SAVING!
# ### 174 / 08 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 576 (10 Oct 2018) - 1579.7 km ..
# SAVING!
# ### 175 / 10 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 578 (10 Oct 2018) - 1606.1 km ..
# SAVING!
# ### 176 / 12 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 580 (10 Oct 2018) - 1576.6 km ..
# SAVING!
# ### 177 / 14 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 582 (10 Oct 2018) - 1563.8 km ..
# SAVING!
# ### 178 / 16 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 584 (10 Oct 2018) - 1562.5 km ..
# SAVING!
# ### 179 / 18 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 586 (10 Oct 2018) - 1562.5 km ..
# SAVING!
# ### 180 / 20 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 588 (10 Oct 2018) - 1561.4 km ..
# SAVING!
# ### 181 / 22 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 590 (10 Oct 2018) - 1564.0 km ..
# SAVING!
# ### 182 / 24 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 592 (10 Oct 2018) - 1559.9 km ..
# SAVING!
# ### 183 / 26 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 594 (10 Oct 2018) - 1554.2 km ..
# SAVING!
# ### 184 / 28 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 596 (10 Oct 2018) - 1552.0 km ..
# SAVING!
# ### 185 / 30 May 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 598 (10 Oct 2018) - 1553.9 km ..
# SAVING!
# ### 186 / 01 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 600 (10 Oct 2018) - 1552.9 km ..
# SAVING!
# ### 187 / 03 Jun 2020.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step
2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 141 (01 Dec 2020) - 491.7 km ..
# SAVING!
# ### 349 / 23 Apr 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 143 (01 Dec 2020) - 477.0 km ..
# SAVING!
# ### 350 / 25 Apr 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 145 (01 Dec 2020) - 475.5 km ..
# SAVING!
# ### 351 / 27 Apr 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 147 (01 Dec 2020) - 482.6 km ..
# SAVING!
# ### 352 / 29 Apr 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 150 (30 Nov 2020) - 495.2 km ..
# SAVING!
# ### 353 / 01 May 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 152 (30 Nov 2020) - 496.7 km ..
# SAVING!
# ### 354 / 03 May 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 154 (30 Nov 2020) - 497.3 km ..
# SAVING!
# ### 355 / 05 May 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 156 (30 Nov 2020) - 496.1 km ..
# SAVING!
# ### 356 / 07 May 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 158 (30 Nov 2020) - 494.5 km ..
# SAVING!
# ### 357 / 09 May 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 160 (30 Nov 2020) - 498.1 km ..
# SAVING!
# ### 358 / 11 May 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 162 (30 Nov 2020) - 497.9 km ..
# SAVING!
# ### 359 / 13 May 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 164 (30 Nov 2020) - 491.7 km ..
# SAVING!
# ### 360 / 15 May 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 166 (30 Nov 2020) - 488.7 km ..
# SAVING!
# ### 361 / 17 May 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 168 (30 Nov 2020) - 485.8 km ..
# SAVING!
# ### 362 / 19 May 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 170 (30 Nov 2020) - 484.6 km ..
# SAVING!
# ### 363 / 21 May 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 172 (30 Nov 2020) - 489.9 km ..
# SAVING!
# ### 364 / 23 May 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 174 (30 Nov 2020) - 494.1 km ..
# SAVING!
# ### 365 / 25 May 2021.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)021) - 314.0 km ..
# SAVING!
# ### 366 / 27 May 2021.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)21) - 280.6 km ..
# SAVING!
# ### 367 / 29 May 2021.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)21) - 296.8 km ..
# SAVING!
# ### 368 / 31 May 2021.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)21) - 307.3 km ..
# SAVING!
# ### 369 / 02 Jun 2021.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)21) - 292.8 km ..
# SAVING!
# ### 370 / 04 Jun 2021.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)021) - 323.4 km ..
# SAVING!
# ### 371 / 06 Jun 2021.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)021) - 368.4 km ..
# SAVING!
# ### 372 / 08 Jun 2021.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)021) - 515.1 km ..
# SAVING!
# ### 373 / 10 Jun 2021.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)021) - 490.8 km ..
# SAVING!
# ### 374 / 12 Jun 2021.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)021) - 503.0 km ..
# SAVING!
# ### 375 / 14 Jun 2021.. ###
# Setting up object ..
#  ..done.
# LAND AHOY! (Particle hit a coastline)020) - 534.5 km ..
# SAVING!
# ### 376 / 16 Jun 2021.. ###
# Setting up object ..
#  ..done.
# NO MOVEMENT! (Particle movement stalled last 3 days) ..
# SAVING!
# ### 377 / 18 Jun 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 240 (21 Oct 2020) - 646.1 km ..
# SAVING!
# ### 378 / 20 Jun 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 244 (19 Oct 2020) - 665.4 km ..
# SAVING!
# ### 379 / 22 Jun 2021.. ###
# Setting up object ..
#  ..done.
# HIT OPEN WATER! () step 246 (19 Oct 2020) - 666.3 km ..
# SAVING!
# ### 380 / 24 Jun 2021.. ###
# Setting up object ..
#  ..done.
# BACKTRACKING: Time step 178 (28 Dec 2020) - 758.9 km ..
